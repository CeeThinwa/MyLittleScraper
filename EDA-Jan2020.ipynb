# %% [markdown]
# ### Loading Jan Data & Packages

# %%
# Load packages
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
import html5lib
import pandas as pd
import numpy as np
import base64
import datetime
from IPython.display import HTML
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
nltk.download('stopwords')
nltk.download('punkt')

# !pip install unidecode
import unidecode
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Requirement already satisfied: unidecode in /usr/local/lib/python3.6/dist-packages (1.1.1)

# %%
# Load data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cleaned_jds = pd.read_csv('/content/drive/My Drive/Data Science/Sentiment Analysis: Automating Search & Analysis/test run output/Jan 2020 from Indeed/Final Analysis files/jd_data_mined_2020-01-13_09.19.40.395290.csv')
print(cleaned_jds.shape, ": original shape of dataframe")

cleaned_jds = pd.DataFrame(cleaned_jds['text'].unique())
cleaned_jds.columns = ['text']
print(cleaned_jds.shape, ": shape of dataframe with only unique jds")

cleaned_jds.head(2)
# Out:
# (924, 2) : original shape of dataframe
# (918, 1) : shape of dataframe with only unique jds
#                                                 text
# 0  caring for the world one person at a time has ...
# 1  facebook s mission is to give people the power...

# %% [markdown]
# ### Overall Functions

# %%
# My dataminer:
def data_miner(url_root='',
               qs=[],
               tag='',
               tag_attribute={'':''}):
  
  print('Mining started at: ',
        str(datetime.datetime.now()),
        ' UTC time.')
  
  urls = []
  for q in qs:
    url = url_root+q
    urls.append(url)

  data_results = []
  for url in urls:
    r = urlopen(url)
    soup = BeautifulSoup(r, "html5lib")
    items_of_interest = soup.find_all(tag, tag_attribute)
    
    l = []
    for item_of_interest in items_of_interest:
      text = item_of_interest.get_text() # to avoid loading the tags
      text = str(text) # to force into a string if not one already
      l.append(text)
      
    data_results.append(l)
  
  print('Your data has '+str(len(data_results))+' entries.')
  print('Mining ended at: ',
        str(datetime.datetime.now()),
        ' UTC time.')
  
  return data_results

# %%
# A part of speech counter
def pos_counter(s = pd.Series(), part_of_speech = ''):
  print('N/B: This function should work with a Pandas series containing lists')
  pos_count = []
  for my_list in s:
    answer = my_list.count(part_of_speech)
    pos_count.append(answer)
  
  print('Resulting values are ', len(pos_count))
  new_s = pd.Series(pos_count)
  return new_s

# %%
# A word associator - connecting each item in a list of words to
# the words immediately preceding and following that item
unwanteds = ['  ', '   ', '    ', '     ', '      ', '       ', '        ',
             '         ', '          ', ' -- ', ' - ']
def word_associator(series=pd.Series(),
                    items=[],
                    unwanteds=unwanteds):
  # Remove any unwanted expressions
  # (this includes whitespace greater then 1 space but less than 11 spaces)
  for unwanted in unwanteds:
    series = series.str.replace(unwanted, ' ')
  
  # Get the word neighbours
  for item in items:
    pattern_a = ' ' + item + ' '
    pattern_b = '-' + item + '-'
    series = series.str.replace(pattern_a, pattern_b)
  
  return series

# %%
# Functions that combined, create a frequency distribution table
def token_creator(series, col_name='tokenized_text', df=pd.DataFrame()):
  tokenized_text = [word_tokenize(i) for i in series]
  df.loc[:, col_name] = tokenized_text
  return df

def word_frequency(df, col_name='tokenized_text',
                   allWords=[]): 
  for wordList in df[col_name]:
    allWords += wordList
  # Get their frequency
  frequency_distribution = nltk.FreqDist(allWords)
  # and save it as a frequency distribution table i.e. a df
  freq_df = pd.DataFrame.from_dict(frequency_distribution, orient='index')
  freq_df.reset_index(level=0, inplace=True)
  freq_df.columns = ['expression','frequency']
  freq_df = freq_df.sort_values(by='frequency', ascending=False)
  return freq_df

# %%
# phrase analyzer
def phrase_reporter(neighbour=pd.Series(), df=pd.DataFrame(),
                    unwanteds=unwanteds, pattern_a='', pattern_b=''):
  print('Warning: Restart raw data and function cells before running this instance of the function')
  neighbour
  neighbour = cleaned_jds['text'] # this should preferably have semi-clean text
  for unwanted in unwanteds:
    neighbour = neighbour.str.replace(unwanted, ' ')
  
  i = 0
  
  neighbour = neighbour.str.replace(pattern_a, pattern_b)
  
  tokens = token_creator(series=neighbour,
                         col_name='tokenized_words')
  
  freq_table = word_frequency(df=tokens,
                             col_name='tokenized_words')
  
  print('Top 5 expressions for: ', '"', pattern_a, '"')
  report = freq_table.loc[freq_table['expression'].str.contains(pattern_b)==True]
  print(report.head(5))
  print(' ')

  print('Total frequency: ', report.frequency.sum())
  print('Total number of expressions: ', report.expression.count())
  print('Minimum frequency: ', report.frequency.min())
  print('Maximum frequency: ', report.frequency.max())
  print(' ')

  average = report.frequency.sum()/report.expression.count()
  print('Therefore, the average expression of ', '"', pattern_a, '"',
        ' has a frequency of ', str(average), ';')
  
  median = report.frequency.median()
  condition = report.loc[report['frequency'] == median]
  print('some median expressions of ', '"', pattern_a, '"',
        ' are ', ' as shown below:')
  print(condition.head(5))
  print('(', '"', pattern_a, '"', ' had ', condition.shape[0],
        ' median expressions')
  print('-----END OF ANALYSIS-----')
  print(' ')
  print('---------------------------------------------------------------------')
  print(' ')
  return

# %%
# A data downloader
def create_download_link( df, title = "Download CSV file", filename = "data.csv"):
  csv = df.to_csv(index =True)
  b64 = base64.b64encode(csv.encode())
  payload = b64.decode()
  html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
  html = html.format(payload=payload,title=title,filename=filename)
  return HTML(html)

# %% [markdown]
# ### Word Frequencies across all text

# %%
# We start by examining the frequency of all words
# Let's create a separate dataset examining this:
words = cleaned_jds['text']

# %%
# Next, we connect words with apostrophes to represent shortened words like:
shorts = ['m', 're', 's']
for short in shorts:
  short_a = ' ' + short + ' '
  short_b = '-' + short + ' '
  words = words.str.replace(short_a, short_b)

# %%
# And call on our functions to do the job for us!
word_tokens = token_creator(series=words, col_name='word_tokenized_text')
word_freq_table = word_frequency(df=word_tokens, col_name='word_tokenized_text')
word_freq_df = word_freq_table

# %%
# Let's test and see that shortened words are functional
test_copy = pd.DataFrame(word_freq_df['expression'])
test_copy.columns = ['word']
truth1 = test_copy['word'].str.contains("-m")
truth2 = test_copy['word'].str.contains("-re")
truth3 = test_copy['word'].str.contains("-s")
truths = [truth1, truth2, truth3]
i=1
for truth in truths:
  t = 'truth'+str(i)
  test_copy.loc[:, t] = truth
  print(test_copy.groupby(t)[t].count())
  print('')
  i+=1
# Out:
# truth1
# False    15210
# True        36
# Name: truth1, dtype: int64
#
# truth2
# False    15229
# True        17
# Name: truth2, dtype: int64
#
# truth3
# False    14723
# True       523
# Name: truth3, dtype: int64

# %% [markdown]
# ### Word Classification

# %%
# Our dataset of interest has the following shape:
word_freq_df = word_freq_df.reset_index(drop=True)
print(word_freq_df.shape)
word_freq_df.head(3)
# Out:
# (15246, 2)
#   expression  frequency
# 0        and      30373
# 1         to      15382
# 2        the      14576

# %%
# The first 50 values of the 'expressions' series becomes a list of queries:
ndf = pd.DataFrame()
ndf = word_freq_df.head(50)
queries = ndf.expression.to_list()

print(len(queries), ' queries were selected')
percentile = len(queries)/word_freq_df.shape[0] * 100
print('These queries were in the top ', percentile, '%')
# Out:
# 50  queries were selected
# These queries were in the top  0.32795487340941887 %

# %%
# Next, mine the parts of speech for each word and save in a list
p_o_s = data_miner(url_root='https://dictionary.cambridge.org/dictionary/english/',
                   qs=queries,
                   tag='span',
                   tag_attribute={'class':'pos dpos'})
# Out:
# Mining started at:  2020-01-30 12:13:53.180656  UTC time.
# Your data has 50 entries.
# Mining ended at:  2020-01-30 12:14:50.959049  UTC time.

# %%
pos_df = pd.DataFrame(ndf['expression'])
pos_df.loc[:, 'Part of Speech'] = p_o_s
pos_df.head(3)
# Out:
#   expression                      Part of Speech
# 0        and          [conjunction, conjunction]
# 1         to  [preposition, adverb, preposition]
# 2        the      [determiner, definite article]

# %%
# Count the number of occurrence of the 3 parts of speech that we wish to
# examine:
# 1. Noun
# 2. Verb
# 3. Pronoun
parts = ['noun', 'verb', 'pronoun']

for part in parts:
  string = part + '_count'
  pos_df.loc[:, string] = pos_counter(pos_df['Part of Speech'], part)
# Out:
# N/B: This function should work with a Pandas series containing lists
# Resulting values are  50
# N/B: This function should work with a Pandas series containing lists
# Resulting values are  50
# N/B: This function should work with a Pandas series containing lists
# Resulting values are  50

# %%
# Now that we have classified the data, let us examine the first 50 results:
pos_df
# Out:
#      expression  ... pronoun_count
# 0           and  ...             0
# 1            to  ...             0
# 2           the  ...             0
# 3            of  ...             0
# 4            in  ...             0
# 5             a  ...             0
# 6          with  ...             0
# 7           for  ...             0
# 8     marketing  ...             0
# 9            or  ...             0
# 10     research  ...             0
# 11           is  ...             0
# 12           as  ...             0
# 13   experience  ...             0
# 14           on  ...             0
# 15          our  ...             1
# 16          you  ...             2
# 17         work  ...             0
# 18         will  ...             0
# 19           be  ...             0
# 20           we  ...             2
# 21          are  ...             0
# 22         team  ...             0
# 23           an  ...             0
# 24         that  ...             3
# 25       skills  ...             0
# 26     business  ...             0
# 27      ability  ...             0
# 28         data  ...             0
# 29          all  ...             2
# 30         this  ...             2
# 31           at  ...             0
# 32   management  ...             0
# 33        other  ...             2
# 34            i  ...             2
# 35    including  ...             0
# 36          new  ...             0
# 37           by  ...             0
# 38        media  ...             0
# 39  development  ...             0
# 40      product  ...             0
# 41         your  ...             1
# 42         from  ...             0
# 43      support  ...             0
# 44         have  ...             0
# 45          amp  ...             0
# 46     required  ...             0
# 47       strong  ...             0
# 48       market  ...             0
# 49          job  ...             0
#
# [50 rows x 5 columns]

# %%
namey = 'pos_word_data_analysed_' + str(datetime.datetime.now()) + '.csv'
create_download_link(pos_df, filename=namey)
# Out:
# <a download="pos_word_data_analysed_2020-01-30 12:14:51.074250.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>

# %% [markdown]
# Therefore, the most frequent nouns out of the 50 most frequent words could be:
# 1.    'in.' - short form for inches / 'IN' - short form for the US state of Indiana
#
# 2.    'A' - short form for amperes / 'A' - the first letter of the English alphabet / 'A' - a musical note / 'A' - a test score
#
# 3.    'marketing'
#
# 4.    'OR' - short form for operating room / 'OR' - short form of the US state of Oregon / 'OR' - short form for Operations Research
#
# 5.    'research'
#
# 6.    'experience'
#
# 7.    'work'
#
# 8.    'will' - mental power / 'will' - an official document of what a person has decided should be done with their money and property after their death
#
# 9.    'team'
#
# 10.    'skills'
#
# 11.    'business'
#
# 12.    'ability'
#
# 13.    'data'
#
# 14.   'management'
#
# 15.   'I' - the ninth letter of the English alphabet / 'i' - the roman numeral of the number 1
#
# 16.   'the new' - new things
#
# 17.   'media'
#
# 18.   'development'
#
# 19.   'product'
#
# 20.   'support'
#
# 21.   'amp' - short form for amperes / 'amp' - an amplifier / 'amp' - the unicode representation of an ampersand
#
# 22.   'market'
#
# 23.   'job'

# %% [markdown]
# The most frequent verbs out of the 50 most frequent words could be:
# 1.   'research'
#
# 2.   'is'
#
# 3.   'experience'
#
# 4.   'work'
#
# 5.   'will'
#
# 6.   'be'
#
# 7.   'are'
#
# 8.   'team'
#
# 9.   'support'
#
# 10.  'have'
#
# 11.  'market'
#
# 12.  'to job' - to do work for different people without being employed by them permanently

# %% [markdown]
# And the most frequent pronouns out of the 50 most frequent words could be:
# 1.   'our'
#
# 2.   'you'
#
# 3.   'we'
#
# 4.   'that' - A [relative pronoun](https://dictionary.cambridge.org/grammar/british-grammar/this-that-these-those?q=this)
#
# 5.   'all' - We can use **all** as a pronoun in formal situations, for example: *All were happy with the outcome.* (less formal: *Everyone was happy with the outcome.*). Usually, all as a pronoun is premodified or postmodified, for instance: *More than 100 people came to the refugee centre. Almost all had lost family members or property or both.*
#
# 6.   'this' - A [relative pronoun](https://dictionary.cambridge.org/grammar/british-grammar/this-that-these-those?q=this)
#
# 7.   'other' - When used as a pronoun, it is the second of two things or people, or the thing or person that is left in a group or set of things, for example: *Hold the racquet in one hand and the ball in the other.*
#
# 8.   'I'
#
# 9.   'your'

# %% [markdown]
# ### EDA: Words & Their Neighbours

# %% [markdown]
# #### Are our classifications of nouns, verbs and pronouns applicable in the data context?
# In this section, word associations for each of the selected members of each class are conducted to find if each word is most frequently used as a noun, a pronoun or a verb.

# %%
tops = ['in', 'a', 'marketing', 'or', 'research' , 'experience', 'work', 'will',
        'team', 'skills', 'business', 'ability', 'data', 'management', 'i',
        'new', 'media', 'development', 'product', 'support', 'amp', 'market',
        'job', 'is', 'be', 'are', 'have', 'our', 'you', 'we', 'that', 'all',
        'this', 'other', 'your']

# %%
i=0
for i in range(len(tops)):
  str_a = ' '+tops[i]+' '
  str_b = '-'+tops[i]+'-'
  phrase_reporter(pattern_a=str_a,
                  pattern_b=str_b)
# Out:
# Top 5 expressions for:  "  in  "
#                expression  frequency
# 935             work-in-a        109
# 842   degree-in-marketing         81
# 598       experience-in-a         79
# 1859        assist-in-the         74
# 1503    experience-in-the         53
#
# Total frequency:  8203
# Total number of expressions:  5167
# Minimum frequency:  1
# Maximum frequency:  109
#
# Therefore, the average expression of  "  in  "  has a frequency of  1.5875749951616025 ;
# some median expressions of   in   are   as shown below:
#                  expression  frequency
# 16173          meals-in-our          1
# 16304     best-in-execution          1
# 16300        assist-in-data          1
# 16444     or-in-development          1
# 3195   schedules-in-nielsen          1
# ( "  in  "  had  4138  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  a  "
#          expression  frequency
# 19728     in-a-fast        164
# 19800     is-a-plus         90
# 19734  or-a-related         64
# 19798     in-a-team         52
# 19756     of-a-team         50
#
# Total frequency:  8072
# Total number of expressions:  4226
# Minimum frequency:  1
# Maximum frequency:  164
#
# Therefore, the average expression of  "  a  "  has a frequency of  1.910080454330336 ;
# some median expressions of   a   are   as shown below:
#                      expression  frequency
# 23578           provided-a-wide          1
# 24032  utilizing-a-consultative          1
# 24026       between-a-naturally          1
# 24124               to-a-career          1
# 24130              find-a-voice          1
# ( "  a  "  had  3061  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  marketing  "
#                         expression  frequency
# 24134           the-marketing-team         56
# 24213             of-marketing-and         42
# 24167  in-marketing-communications         37
# 24309            the-marketing-and         36
# 24259              in-marketing-or         33
#
# Total frequency:  4708
# Total number of expressions:  2922
# Minimum frequency:  1
# Maximum frequency:  56
#
# Therefore, the average expression of  "  marketing  "  has a frequency of  1.6112251882272417 ;
# some median expressions of   marketing   are   as shown below:
#                        expression  frequency
# 24485  junior-marketing-associate          1
# 24486      global-marketing-teams          1
# 24482           bu-marketing-team          1
# 24483         b2b-marketing-teams          1
# 24484        through-marketing-if          1
# ( "  marketing  "  had  2259  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  or  "
#                    expression  frequency
# 27125           status-or-any         60
# 27072  identity-or-expression         48
# 27126    degree-or-equivalent         38
# 27195          state-or-local         37
# 27064        assistance-or-an         35
#
# Total frequency:  4093
# Total number of expressions:  2449
# Minimum frequency:  1
# Maximum frequency:  60
#
# Therefore, the average expression of  "  or  "  has a frequency of  1.671294405879951 ;
# some median expressions of   or   are   as shown below:
#                           expression  frequency
# 27925         activities-or-historic          1
# 29239               resumes-or-calls          1
# 29242            chimp-or-equivalent          1
# 29243           project-or-situation          1
# 29281  constructions-or-architecture          1
# ( "  or  "  had  1910  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  research  "
#                        expression  frequency
# 29616         market-research-and         64
# 29725          market-research-to         29
# 29589        the-research-analyst         19
# 29600             to-research-and         18
# 29615  market-research-experience         18
#
# Total frequency:  3512
# Total number of expressions:  2313
# Minimum frequency:  1
# Maximum frequency:  64
#
# Therefore, the average expression of  "  research  "  has a frequency of  1.5183744055339385 ;
# some median expressions of   research   are   as shown below:
#                                             expression  frequency
# 24834  including-marketing-research-marketing-strategy          1
# 30406                         opinion-research-through          1
# 30408                              s-research-projects          1
# 30409                        understand-research-needs          1
# 30410                     developing-research-approach          1
# ( "  research  "  had  1820  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  experience  "
#                 expression  frequency
# 31838     of-experience-in         87
# 31912  years-experience-in         73
# 31837  and-experience-with         29
# 31818   of-experience-with         28
# 31817     -experience-with         25
#
# Total frequency:  2886
# Total number of expressions:  1778
# Minimum frequency:  1
# Maximum frequency:  87
#
# Therefore, the average expression of  "  experience  "  has a frequency of  1.623172103487064 ;
# some median expressions of   experience   are   as shown below:
#                       expression  frequency
# 32427              -experience-4          1
# 31891       build-experience-and          1
# 31892        gain-experience-and          1
# 31893        must-experience-and          1
# 31894  equivalent-experience-the          1
# ( "  experience  "  had  1408  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  work  "
#                   expression  frequency
# 33607             to-work-in        153
# 33608  to-work-independently         89
# 33626           to-work-with         69
# 33621      will-work-closely         57
# 33611         will-work-with         40
#
# Total frequency:  2602
# Total number of expressions:  1327
# Minimum frequency:  1
# Maximum frequency:  153
#
# Therefore, the average expression of  "  work  "  has a frequency of  1.9608138658628484 ;
# some median expressions of   work   are   as shown below:
#                      expression  frequency
# 34923            they-work-with          1
# 34927              on-work-with          1
# 34926  programmatic-work-across          1
# 34924    30lbs-work-environment          1
# 34925      its-work-familiarity          1
# ( "  work  "  had  1033  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  will  "
#                     expression  frequency
# 34943              you-will-be        146
# 34933  applicants-will-receive         84
# 34938            you-will-work         55
# 35023            you-will-have         45
# 34937        candidate-will-be         40
#
# Total frequency:  2552
# Total number of expressions:  1094
# Minimum frequency:  1
# Maximum frequency:  146
#
# Therefore, the average expression of  "  will  "  has a frequency of  2.3327239488117 ;
# some median expressions of   will   are   as shown below:
#                   expression  frequency
# 35928  consultant-will-drive          1
# 35940        you-will-really          1
# 35931   efforts-will-require          1
# 35892      work-will-include          1
# 35943    analytics-will-lead          1
# ( "  will  "  had  738  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  team  "
#                expression  frequency
# 36040           a-team-of         51
# 36073  a-team-environment         40
# 36067   marketing-team-to         28
# 36162       a-team-player         20
# 36053        the-team-and         18
#
# Total frequency:  2100
# Total number of expressions:  1283
# Minimum frequency:  1
# Maximum frequency:  51
#
# Therefore, the average expression of  "  team  "  has a frequency of  1.636788776305534 ;
# some median expressions of   team   are   as shown below:
#                        expression  frequency
# 36922                 web-team-to          1
# 36896  development-team-assisting          1
# 36895             paced-team-this          1
# 36894            the-team-develop          1
# 36893     management-team-leaders          1
# ( "  team  "  had  1037  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  skills  "
#                          expression  frequency
# 37371          knowledge-skills-and         45
# 37391  communication-skills-ability         34
# 37535      communication-skills-and         29
# 37387     organizational-skills-and         27
# 37342     communication-skills-both         25
#
# Total frequency:  1951
# Total number of expressions:  1059
# Minimum frequency:  1
# Maximum frequency:  45
#
# Therefore, the average expression of  "  skills  "  has a frequency of  1.8423040604343721 ;
# some median expressions of   skills   are   as shown below:
#                                expression  frequency
# 37437    storytelling-skills-successfully          1
# 37435    organizational-skills-especially          1
# 37438     powerpoint-skills-spss-skills-a          1
# 37434               research-skills-solid          1
# 37441  jobsectionheader-skills-experience          1
# ( "  skills  "  had  806  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  business  "
#                        expression  frequency
# 38371       small-business-expand         29
# 38456            the-business-and         17
# 38515  in-business-administration         16
# 38448       in-business-marketing         14
# 38374  new-business-opportunities         13
#
# Total frequency:  1769
# Total number of expressions:  1229
# Minimum frequency:  1
# Maximum frequency:  29
#
# Therefore, the average expression of  "  business  "  has a frequency of  1.4393816110659072 ;
# some median expressions of   business   are   as shown below:
#                                           expression  frequency
# 39177                correct-business-correspondence          1
# 39175                                of-business-cob          1
# 39173                            access-business-and          1
# 39172  in-business-administration-business-analytics          1
# 39171                 matching-business-requirements          1
# ( "  business  "  had  988  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  ability  "
#                     expression  frequency
# 39596           the-ability-to        294
# 39603        skills-ability-to        129
# 39617           and-ability-to        102
# 39614  demonstrated-ability-to         52
# 39637        proven-ability-to         48
#
# Total frequency:  1738
# Total number of expressions:  529
# Minimum frequency:  1
# Maximum frequency:  294
#
# Therefore, the average expression of  "  ability  "  has a frequency of  3.2854442344045367 ;
# some median expressions of   ability   are   as shown below:
#                       expression  frequency
# 39936  correspondence-ability-to          1
# 39938         success-ability-to          1
# 39934       timelines-ability-to          1
# 39933      preferred-ability-and          1
# 39928         thinker-ability-to          1
# ( "  ability  "  had  346  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  data  "
#                expression  frequency
# 40125   and-data-analysis         30
# 40167         of-data-and         15
# 40236     large-data-sets         12
# 40724    analyze-data-and         10
# 40164  and-data-analytics         10
#
# Total frequency:  1677
# Total number of expressions:  1204
# Minimum frequency:  1
# Maximum frequency:  30
#
# Therefore, the average expression of  "  data  "  has a frequency of  1.3928571428571428 ;
# some median expressions of   data   are   as shown below:
#                            expression  frequency
# 40363             collected-data-seek          1
# 40354                    this-data-to          1
# 40362   illustrating-data-graphically          1
# 40353                  party-data-and          1
# 40355  entrepreneurship-data-analysis          1
# ( "  data  "  had  960  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  management  "
#                           expression  frequency
# 41352      project-management-skills         46
# 41330         project-management-and         34
# 41476         time-management-skills         29
# 41411              and-management-of         23
# 41389  project-management-experience         19
#
# Total frequency:  1337
# Total number of expressions:  878
# Minimum frequency:  1
# Maximum frequency:  46
#
# Therefore, the average expression of  "  management  "  has a frequency of  1.5227790432801822 ;
# some median expressions of   management   are   as shown below:
#                            expression  frequency
# 42105    financial-management-ensures          1
# 42106       vendor-management-manages          1
# 42107  service-management-development          1
# 42110           budget-management-for          1
# 42111            and-management-teams          1
# ( "  management  "  had  725  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  i  "
#           expression  frequency
# 42230  workplace-i-i          9
# 42221       form-i-9          8
# 42257         -i-the          8
# 42386        -i-this          6
# 42261        com-i-i          6
#
# Total frequency:  859
# Total number of expressions:  701
# Minimum frequency:  1
# Maximum frequency:  9
#
# Therefore, the average expression of  "  i  "  has a frequency of  1.225392296718973 ;
# some median expressions of   i   are   as shown below:
#                       expression  frequency
# 42685        include-i-formative          1
# 42687       audiences-i-efficacy          1
# 42677                   -i-veeva          1
# 42678  simultaneously-i-performs          1
# 42679                  needed-i-          1
# ( "  i  "  had  612  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  new  "
#                   expression  frequency
# 42932  creating-new-products         29
# 42941            in-new-york         26
# 43117        of-new-products         19
# 43159       and-new-business         14
# 42930      states-new-jersey         11
#
# Total frequency:  1275
# Total number of expressions:  870
# Minimum frequency:  1
# Maximum frequency:  29
#
# Therefore, the average expression of  "  new  "  has a frequency of  1.4655172413793103 ;
# some median expressions of   new   are   as shown below:
#                  expression  frequency
# 42945           and-new-and          1
# 42944    of-new-information          1
# 43121        to-new-markets          1
# 42949  assigned-new-product          1
# 42948           into-new-or          1
# ( "  new  "  had  713  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  media  "
#                    expression  frequency
# 43809        social-media-and         52
# 43807  social-media-platforms         38
# 43806   social-media-accounts         26
# 43844   social-media-channels         23
# 43901    social-media-content         23
#
# Total frequency:  1248
# Total number of expressions:  739
# Minimum frequency:  1
# Maximum frequency:  52
#
# Therefore, the average expression of  "  media  "  has a frequency of  1.6887686062246279 ;
# some median expressions of   media   are   as shown below:
#                        expression  frequency
# 44252        prior-media-research          1
# 44253  development-media-planning          1
# 44254     social-media-journalism          1
# 44255        social-media-interns          1
# 44256            pr-media-digital          1
# ( "  media  "  had  579  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  development  "
#                      expression  frequency
# 44544        the-development-of        118
# 44550       the-development-and         68
# 44549        and-development-of         27
# 44548   product-development-and         24
# 44580  business-development-and         14
#
# Total frequency:  1247
# Total number of expressions:  755
# Minimum frequency:  1
# Maximum frequency:  118
#
# Therefore, the average expression of  "  development  "  has a frequency of  1.651655629139073 ;
# some median expressions of   development   are   as shown below:
#                        expression  frequency
# 44642       estate-development-we          1
# 44664           plan-development-          1
# 44663  career-development-support          1
# 44662   plan-development-oversees          1
# 44660   amp-development-marketing          1
# ( "  development  "  had  610  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  product  "
#                     expression  frequency
# 45305  new-product-development         25
# 45521        and-product-teams         15
# 45381  and-product-development         11
# 45383  the-product-development         10
# 45423   in-product-development         10
#
# Total frequency:  1153
# Total number of expressions:  787
# Minimum frequency:  1
# Maximum frequency:  25
#
# Therefore, the average expression of  "  product  "  has a frequency of  1.4650571791613722 ;
# some median expressions of   product   are   as shown below:
#                                   expression  frequency
# 46069             receiver-product-lifecycle          1
# 46068                  and-product-lifecycle          1
# 46070  a-product-management-product-strategy          1
# 45311              of-product-communications          1
# 45314                   and-product-insights          1
# ( "  product  "  had  646  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  support  "
#              expression  frequency
# 46079    to-support-the         65
# 46083     in-support-of         53
# 46088  will-support-the         15
# 46123   and-support-the         13
# 46094    to-support-our         12
#
# Total frequency:  1084
# Total number of expressions:  717
# Minimum frequency:  1
# Maximum frequency:  65
#
# Therefore, the average expression of  "  support  "  has a frequency of  1.511854951185495 ;
# some median expressions of   support   are   as shown below:
#                    expression  frequency
# 46504  account-support-engage          1
# 46488       will-support-wolf          1
# 46489  will-support-marketing          1
# 46490        that-support-all          1
# 46491  partners-support-media          1
# ( "  support  "  had  611  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  amp  "
#                          expression  frequency
# 46794                       r-amp-d         95
# 46889   duties-amp-responsibilities         37
# 46793           johnson-amp-johnson         27
# 46831  marketing-amp-communications         18
# 46825           sales-amp-marketing         16
#
# Total frequency:  1059
# Total number of expressions:  589
# Minimum frequency:  1
# Maximum frequency:  95
#
# Therefore, the average expression of  "  amp  "  has a frequency of  1.797962648556876 ;
# some median expressions of   amp   are   as shown below:
#                      expression  frequency
# 46824  written-amp-presentation          1
# 46853       account-amp-project          1
# 46852   maternity-amp-paternity          1
# 46850           salary-amp-paid          1
# 46849      benefits-amp-culture          1
# ( "  amp  "  had  466  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  market  "
#                     expression  frequency
# 47400       of-market-research         33
# 47422      and-market-research         29
# 47405       in-market-research         29
# 47419  conduct-market-research         26
# 47381        a-market-research         14
#
# Total frequency:  1044
# Total number of expressions:  627
# Minimum frequency:  1
# Maximum frequency:  33
#
# Therefore, the average expression of  "  market  "  has a frequency of  1.6650717703349283 ;
# some median expressions of   market   are   as shown below:
#                        expression  frequency
# 47893               the-market-we          1
# 47894          on-market-economic          1
# 47895    major-market-minneapolis          1
# 47896         the-market-navigate          1
# 47897  international-market-share          1
# ( "  market  "  had  504  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  job  "
#                              expression  frequency
# 48006               our-job-application         31
# 48029           essential-job-functions         22
# 48054              this-job-description         21
# 48042  jobsectionheader-job-description         18
# 48070                         -job-duty         18
#
# Total frequency:  918
# Total number of expressions:  501
# Minimum frequency:  1
# Maximum frequency:  31
#
# Therefore, the average expression of  "  job  "  has a frequency of  1.8323353293413174 ;
# some median expressions of   job   are   as shown below:
#                          expression  frequency
# 48025              and-job-openings          1
# 48024  changes-job-responsibilities          1
# 48021               summer-job-made          1
# 48019     following-job-description          1
# 48017            the-job-importance          1
# ( "  job  "  had  366  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  is  "
#                   expression  frequency
# 48532              this-is-a         80
# 48511          mission-is-to         61
# 48515  facebook-is-committed         29
# 48512             this-is-an         28
# 48643              it-is-not         21
#
# Total frequency:  3410
# Total number of expressions:  2087
# Minimum frequency:  1
# Maximum frequency:  80
#
# Therefore, the average expression of  "  is  "  has a frequency of  1.6339242932438907 ;
# some median expressions of   is   are   as shown below:
#                   expression  frequency
# 49709    clients-is-required          1
# 49696      skin-is-instantly          1
# 49697        neogen-is-there          1
# 49693       marketing-is-fun          1
# 49712  flexibility-is-needed          1
# ( "  is  "  had  1606  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  be  "
#                 expression  frequency
# 50593         must-be-able        120
# 50605  will-be-responsible        112
# 50588             to-be-an         57
# 50604            will-be-a         55
# 50603              to-be-a         47
#
# Total frequency:  2397
# Total number of expressions:  876
# Minimum frequency:  1
# Maximum frequency:  120
#
# Therefore, the average expression of  "  be  "  has a frequency of  2.7363013698630136 ;
# some median expressions of   be   are   as shown below:
#                 expression  frequency
# 51414     only-be-required          1
# 51415      to-be-effective          1
# 51416          to-be-fully          1
# 51410          to-be-built          1
# 51411  will-be-inquisitive          1
# ( "  be  "  had  598  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  are  "
#            expression  frequency
# 51489  we-are-looking        106
# 51498       we-are-an         56
# 51499  we-are-seeking         43
# 51589        we-are-a         41
# 51481       you-are-a         40
#
# Total frequency:  2172
# Total number of expressions:  1147
# Minimum frequency:  1
# Maximum frequency:  106
#
# Therefore, the average expression of  "  are  "  has a frequency of  1.893635571054926 ;
# some median expressions of   are   are   as shown below:
#                  expression  frequency
# 52604    resources-are-made          1
# 52603   centers-are-located          1
# 52609  duties-are-performed          1
# 52607   amazon-are-expected          1
# 52606          we-are-happy          1
# ( "  are  "  had  899  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  have  "
#           expression  frequency
# 52619     you-have-a         51
# 52647  will-have-the         38
# 52651    will-have-a         38
# 52645    must-have-a         34
# 52680      we-have-a         28
#
# Total frequency:  1077
# Total number of expressions:  516
# Minimum frequency:  1
# Maximum frequency:  51
#
# Therefore, the average expression of  "  have  "  has a frequency of  2.0872093023255816 ;
# some median expressions of   have   are   as shown below:
#                       expression  frequency
# 53119           we-have-provided          1
# 53121              who-have-dual          1
# 53120  innovations-have-resulted          1
# 53125   will-have-administrative          1
# 53123           that-have-played          1
# ( "  have  "  had  388  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  our  "
#                expression  frequency
# 53180       join-our-team         40
# 53132          in-our-job         31
# 53232     for-our-clients         31
# 53131    heart-our-global         29
# 53130  through-our-family         29
#
# Total frequency:  2732
# Total number of expressions:  1884
# Minimum frequency:  1
# Maximum frequency:  40
#
# Therefore, the average expression of  "  our  "  has a frequency of  1.4501061571125264 ;
# some median expressions of   our   are   as shown below:
#                  expression  frequency
# 54247      runs-our-interns          1
# 54262        with-our-award          1
# 54261      that-our-success          1
# 54260  through-our-employee          1
# 54259          in-our-staff          1
# ( "  our  "  had  1518  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  you  "
#           expression  frequency
# 55065     if-you-are        102
# 55056    what-you-ll         50
# 55013    if-you-need         49
# 55011  role-you-will         42
# 55214  what-you-will         32
#
# Total frequency:  2739
# Total number of expressions:  1422
# Minimum frequency:  1
# Maximum frequency:  102
#
# Therefore, the average expression of  "  you  "  has a frequency of  1.9261603375527425 ;
# some median expressions of   you   are   as shown below:
#                     expression  frequency
# 56427  who-you-are-you-believe          1
# 56429            trust-you-set          1
# 56428    environments-you-have          1
# 56433       procedures-you-are          1
# 56432      organized-you-enjoy          1
# ( "  you  "  had  1061  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  we  "
#               expression  frequency
# 56684            -we-are         40
# 56466         who-we-are         36
# 56438    together-we-can         30
# 56437      whether-we-re         30
# 56439  communities-we-re         29
#
# Total frequency:  2506
# Total number of expressions:  1618
# Minimum frequency:  1
# Maximum frequency:  40
#
# Therefore, the average expression of  "  we  "  has a frequency of  1.5488257107540173 ;
# some median expressions of   we   are   as shown below:
#               expression  frequency
# 57310            i-we-ll          1
# 57324     online-we-hire          1
# 57323        win-we-will          1
# 57322  us-we-immediately          1
# 57321     others-we-have          1
# ( "  we  "  had  1253  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  that  "
#                   expression  frequency
# 58053  company-that-connects         29
# 58137        ensure-that-the         15
# 58213        ensure-that-all         12
# 58267           team-that-is         12
# 58067        those-that-must          9
#
# Total frequency:  2051
# Total number of expressions:  1541
# Minimum frequency:  1
# Maximum frequency:  29
#
# Therefore, the average expression of  "  that  "  has a frequency of  1.3309539260220635 ;
# some median expressions of   that   are   as shown below:
#                     expression  frequency
# 59397       plan-that-supports          1
# 59372             and-that-new          1
# 59394  strategy-that-addresses          1
# 59373    organization-that-won          1
# 59398    culture-that-inspires          1
# ( "  that  "  had  1274  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  all  "
#                    expression  frequency
# 59594  employer-all-qualified         35
# 59655           at-all-levels         34
# 59743       and-all-qualified         20
# 59609         with-all-levels         18
# 59632        of-all-marketing         13
#
# Total frequency:  1621
# Total number of expressions:  1050
# Minimum frequency:  1
# Maximum frequency:  35
#
# Therefore, the average expression of  "  all  "  has a frequency of  1.5438095238095237 ;
# some median expressions of   all   are   as shown below:
#                            expression  frequency
# 42298  for-i-all-i-people-i-all-i-the          1
# 59604               resolve-all-guest          1
# 59608      necessary-all-departmental          1
# 59610                via-all-channels          1
# 59612       opportunity-all-qualified          1
# ( "  all  "  had  819  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  this  "
#               expression  frequency
# 60683  for-this-position         99
# 60644       in-this-role         83
# 60667        of-this-job         38
# 60717   of-this-position         37
# 60659      for-this-role         18
#
# Total frequency:  1539
# Total number of expressions:  904
# Minimum frequency:  1
# Maximum frequency:  99
#
# Therefore, the average expression of  "  this  "  has a frequency of  1.7024336283185841 ;
# some median expressions of   this   are   as shown below:
#                      expression  frequency
# 60740       translate-this-into          1
# 60741  university-this-involves          1
# 60744           world-this-role          1
# 60745      business-this-person          1
# 60746  on-this-team-this-person          1
# ( "  this  "  had  736  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  other  "
#                      expression  frequency
# 61547  any-other-characteristic         70
# 61661       and-other-marketing         23
# 61630           any-other-basis         21
# 61571      perform-other-duties         19
# 61610     performs-other-duties         16
#
# Total frequency:  1343
# Total number of expressions:  746
# Minimum frequency:  1
# Maximum frequency:  70
#
# Therefore, the average expression of  "  other  "  has a frequency of  1.8002680965147453 ;
# some median expressions of   other   are   as shown below:
#                      expression  frequency
# 61886            any-other-form          1
# 61882  clients-other-attributes          1
# 61883            with-other-abi          1
# 61884              -other-stuff          1
# 61889        posts-other-duties          1
# ( "  other  "  had  556  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Top 5 expressions for:  "  your  "
#                   expression  frequency
# 62364    of-your-application         13
# 62361  with-your-application         12
# 62359      into-your-usajobs         10
# 62510     submit-your-resume          8
# 62388       send-your-resume          7
#
# Total frequency:  1083
# Total number of expressions:  711
# Minimum frequency:  1
# Maximum frequency:  13
#
# Therefore, the average expression of  "  your  "  has a frequency of  1.5232067510548524 ;
# some median expressions of   your   are   as shown below:
#                    expression  frequency
# 62662       and-your-personal          1
# 62663     develop-your-skills          1
# 62665         matter-your-job          1
# 62666  lost-your-contribution          1
# 62667    support-your-project          1
# ( "  your  "  had  537  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %% [markdown]
# #### What words are associated with the top nouns, verbs and pronouns?
# In this section, word associations for each of the top noun expressions and the shortlisted nouns were studied jointly.

# %% [markdown]
# ##### *Top Noun Expressions (Based on the top 5 values for each noun association independent of the other words)*

# %% [markdown]
# ###### **Ability**
# Top expression:  *'ability to'*

# %%
# Let's examine the noun and its descriptor
my_list_a = [' ability ','ability ',' ability']
my_list_b = ['-ability-','ability-','-ability']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %%
# Let's examine the noun and its descriptor
my_list_a = ['ability to ','ability to multi ',' ability to',' ability to ']
my_list_b = ['ability-to-','ability-to-multi-','-ability-to','-ability-to-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %%
# Let's examine the noun and its descriptor
my_list_a = ['ability to work ','ability to work with a ',
             'ability to work with all ','ability to work in ',
             'ability to work in a ','ability to work in an ',
             'ability to manage ','ability to manage multiple ',
             'ability to manage a ','ability to communicate ',
             'ability to prioritize ']
my_list_b = ['ability-to-work-','ability-to-work-with-a-',
             'ability-to-work-with-all-','ability-to-work-in-',
             'ability-to-work-in-a-','ability-to-work-in-an-',
             'ability-to-manage-','ability-to-manage-multiple-',
             'ability-to-manage-a-','ability-to-communicate-',
             'ability-to-prioritize-']

i=0
for i in range(11):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " ability to work  "
#                          expression  frequency
# 312   ability-to-work-independently         67
# 3195             ability-to-work-in         57
# 1820           ability-to-work-with         26
# 1779    ability-to-work-effectively         24
# 5438           ability-to-work-well         23
#
# Total frequency:  292
# Total number of expressions:  51
# Minimum frequency:  1
# Maximum frequency:  67
#
# Therefore, the average expression of  " ability to work  "  has a frequency of  5.7254901960784315 ;
# some median expressions of  " ability to work  "  are   as shown below:
#                         expression  frequency
# 14192  dictationability-to-work-as          1
# 12398     ability-to-work-multiple          1
# 14632         ability-to-work-from          1
# 11796      ability-to-work-without          1
# 12167           ability-to-work-10          1
# ( " ability to work  "  had  29  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " ability to work with a  "
#                            expression  frequency
# 14789     ability-to-work-with-a-high          1
# 14790  ability-to-work-with-a-desktop          1
# 14791  ability-to-work-with-a-variety          1
# 14792     ability-to-work-with-a-wide          1
#
# Total frequency:  4
# Total number of expressions:  4
# Minimum frequency:  1
# Maximum frequency:  1
#
# Therefore, the average expression of  " ability to work with a  "  has a frequency of  1.0 ;
# some median expressions of  " ability to work with a  "  are   as shown below:
#                            expression  frequency
# 14789     ability-to-work-with-a-high          1
# 14790  ability-to-work-with-a-desktop          1
# 14791  ability-to-work-with-a-variety          1
# 14792     ability-to-work-with-a-wide          1
# ( " ability to work with a  "  had  4  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " ability to work with all  "
#                                   expression  frequency
# 14796    ability-to-work-with-all-management          1
# 14795        ability-to-work-with-all-levels          1
# 14794         ability-to-work-with-all-teams          1
# 14797  ability-to-work-with-all-stakeholders          1
#
# Total frequency:  4
# Total number of expressions:  4
# Minimum frequency:  1
# Maximum frequency:  1
#
# Therefore, the average expression of  " ability to work with all  "  has a frequency of  1.0 ;
# some median expressions of  " ability to work with all  "  are   as shown below:
#                                   expression  frequency
# 14796    ability-to-work-with-all-management          1
# 14795        ability-to-work-with-all-levels          1
# 14794         ability-to-work-with-all-teams          1
# 14797  ability-to-work-with-all-stakeholders          1
# ( " ability to work with all  "  had  4  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " ability to work in  "
#                        expression  frequency
# 14798        ability-to-work-in-a         46
# 14800    ability-to-work-in-teams          2
# 14801       ability-to-work-in-an          2
# 14806     ability-to-work-in-both          1
# 14802  ability-to-work-in-develop          1
#
# Total frequency:  57
# Total number of expressions:  10
# Minimum frequency:  1
# Maximum frequency:  46
#
# Therefore, the average expression of  " ability to work in  "  has a frequency of  5.7 ;
# some median expressions of  " ability to work in  "  are   as shown below:
#                         expression  frequency
# 14806      ability-to-work-in-both          1
# 14802   ability-to-work-in-develop          1
# 14805       ability-to-work-in-our          1
# 14804    ability-to-work-in-either          1
# 14799  ability-to-work-in-isolated          1
# ( " ability to work in  "  had  7  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " ability to work in a  "
#                          expression  frequency
# 14810     ability-to-work-in-a-fast         21
# 14812     ability-to-work-in-a-team          8
# 14815   ability-to-work-in-a-matrix          3
# 14819    ability-to-work-in-a-multi          3
# 14821  ability-to-work-in-a-varying          1
#
# Total frequency:  46
# Total number of expressions:  15
# Minimum frequency:  1
# Maximum frequency:  21
#
# Therefore, the average expression of  " ability to work in a  "  has a frequency of  3.066666666666667 ;
# some median expressions of  " ability to work in a  "  are   as shown below:
#                           expression  frequency
# 14821   ability-to-work-in-a-varying          1
# 14809   ability-to-work-in-a-rapidly          1
# 14811  ability-to-work-in-a-deadline          1
# 14816   ability-to-work-in-a-teaming          1
# 14817     ability-to-work-in-a-group          1
# ( " ability to work in a  "  had  11  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " ability to work in an  "
#                                expression  frequency
# 14823     ability-to-work-in-an-extremely          1
# 14824  ability-to-work-in-an-organization          1
#
# Total frequency:  2
# Total number of expressions:  2
# Minimum frequency:  1
# Maximum frequency:  1
#
# Therefore, the average expression of  " ability to work in an  "  has a frequency of  1.0 ;
# some median expressions of  " ability to work in an  "  are   as shown below:
#                                expression  frequency
# 14823     ability-to-work-in-an-extremely          1
# 14824  ability-to-work-in-an-organization          1
# ( " ability to work in an  "  had  2  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " ability to manage  "
#                        expression  frequency
# 14825  ability-to-manage-multiple         35
# 14833  ability-to-manage-projects          5
# 14828         ability-to-manage-a          5
# 14826   ability-to-manage-complex          3
# 14835       ability-to-manage-and          3
#
# Total frequency:  79
# Total number of expressions:  30
# Minimum frequency:  1
# Maximum frequency:  35
#
# Therefore, the average expression of  " ability to manage  "  has a frequency of  2.6333333333333333 ;
# some median expressions of  " ability to manage  "  are   as shown below:
#                         expression  frequency
# 14846      ability-to-manage-large          1
# 14851  ability-to-manage-ambiguity          1
# 14842    ability-to-manage-project          1
# 14841      ability-to-manage-small          1
# 14837       ability-to-manage-time          1
# ( " ability to manage  "  had  22  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " ability to manage multiple  "
#                                    expression  frequency
# 14855     ability-to-manage-multiple-projects         25
# 14861   ability-to-manage-multiple-priorities          3
# 14856       ability-to-manage-multiple-market          1
# 14862  ability-to-manage-multiple-assignments          1
# 14858        ability-to-manage-multiple-tasks          1
#
# Total frequency:  35
# Total number of expressions:  9
# Minimum frequency:  1
# Maximum frequency:  25
#
# Therefore, the average expression of  " ability to manage multiple  "  has a frequency of  3.888888888888889 ;
# some median expressions of  " ability to manage multiple  "  are   as shown below:
#                                    expression  frequency
# 14856       ability-to-manage-multiple-market          1
# 14862  ability-to-manage-multiple-assignments          1
# 14858        ability-to-manage-multiple-tasks          1
# 14859    ability-to-manage-multiple-deadlines          1
# 14860         ability-to-manage-multiple-work          1
# ( " ability to manage multiple  "  had  7  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " ability to manage a  "
#                         expression  frequency
# 14867     ability-to-manage-a-high          2
# 14866     ability-to-manage-a-wide          1
# 14865  ability-to-manage-a-variety          1
# 14864  ability-to-manage-a-diverse          1
#
# Total frequency:  5
# Total number of expressions:  4
# Minimum frequency:  1
# Maximum frequency:  2
#
# Therefore, the average expression of  " ability to manage a  "  has a frequency of  1.25 ;
# some median expressions of  " ability to manage a  "  are   as shown below:
#                         expression  frequency
# 14866     ability-to-manage-a-wide          1
# 14865  ability-to-manage-a-variety          1
# 14864  ability-to-manage-a-diverse          1
# ( " ability to manage a  "  had  3  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " ability to communicate  "
#                                expression  frequency
# 14868  ability-to-communicate-effectively         15
# 14869          ability-to-communicate-and          6
# 14873         ability-to-communicate-with          6
# 14870      ability-to-communicate-complex          5
# 14874      ability-to-communicate-clearly          2
#
# Total frequency:  45
# Total number of expressions:  16
# Minimum frequency:  1
# Maximum frequency:  15
#
# Therefore, the average expression of  " ability to communicate  "  has a frequency of  2.8125 ;
# some median expressions of  " ability to communicate  "  are   as shown below:
#                                expression  frequency
# 14879  ability-to-communicate-statistical          1
# 14878           ability-to-communicate-at          1
# 14876       ability-to-communicate-verbal          1
# 14880     ability-to-communicate-directly          1
# 14875       ability-to-communicate-across          1
# ( " ability to communicate  "  had  11  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " ability to prioritize  "
#                            expression  frequency
# 14886       ability-to-prioritize-and         16
# 14884  ability-to-prioritize-multiple          9
# 14889      ability-to-prioritize-work          4
# 14892      ability-to-prioritize-time          1
# 14891  ability-to-prioritize-organize          1
#
# Total frequency:  42
# Total number of expressions:  16
# Minimum frequency:  1
# Maximum frequency:  16
#
# Therefore, the average expression of  " ability to prioritize  "  has a frequency of  2.625 ;
# some median expressions of  " ability to prioritize  "  are   as shown below:
#                               expression  frequency
# 14892         ability-to-prioritize-time          1
# 14891     ability-to-prioritize-organize          1
# 14893  ability-to-prioritize-exceptional          1
# 14890  ability-to-prioritize-effectively          1
# 14894      ability-to-prioritize-clearly          1
# ( " ability to prioritize  "  had  13  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %% [markdown]
# ###### **Development**
# Top expression:  *'the development of'*

# %%
# Let's examine the noun and its descriptor
my_list_a = [' development ','development ',' development']
my_list_b = ['-development-','development-','-development']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %%
my_list_a = ['the development of ',' the development of',' the development of ']
my_list_b = ['the-development-of-','-the-development-of','-the-development-of-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %%
my_list_a = ['the development of the ','the development of new ','the development of marketing ']
my_list_b = ['the-development-of-the-','the-development-of-new-','the-development-of-marketing-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %%
my_list_a = [' in the development of',' to the development of',' on the development of']
my_list_b = ['-in-the-development-of','-to-the-development-of','-on-the-development-of']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %% [markdown]
# ###### **Media**
# Top expression:  *'social media and'*

# %%
# Let's examine the noun and its descriptor
my_list_a = [' social media ','social media ',' social media']
my_list_b = ['-social-media-','social-media-','-social-media']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %%
my_list_a = ['and social media ',' and social media',' and social media ']
my_list_b = ['and-social-media-','-and-social-media','-and-social-media-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %%
# What insights can we derive around media?
my_list_a = [' social media and ','social media and ',' social media and']
my_list_b = ['-social-media-and-','social-media-and-','-social-media-and']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %%
# What insights can we derive around media?
my_list_a = ['social media and digital ','social media and content ']
my_list_b = ['social-media-and-digital-','social-media-and-content-']

i=0
for i in range(2):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %%
# What insights can we derive around media?
my_list_a = [' of social media']
my_list_b = ['-of-social-media']

i=0
for i in range(1):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %%
my_list_a = [' the social media and content coordinator',
             '-position objectives the social media and content coordinator',
             ' and internal communications the social media and content coordinator']
my_list_b = ['-the-social-media-and-content-coordinator',
             '-position-objectives-the-social-media-and-content-coordinator',
             '-and-internal-communications-the-social-media-and-content-coordinator']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %% [markdown]
# ###### **Experience**
# Top expression:  *'of experience in'*

# %%
# Examine the noun and its descriptor
my_list_a = [' experience ','experience ',' experience',]
my_list_b = ['-experience-','experience-','-experience']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %%
my_list_a = [' of experience in ',' of experience in a ',' of experience in the ',]
my_list_b = ['-of-experience-in-','-of-experience-in-a-','-of-experience-in-the-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %%
# What areas should the candidate be experienced in?
my_list_a = [' of experience in ',' of experience in a ',' of experience in the ',]
my_list_b = ['-of-experience-in-','-of-experience-in-a-','-of-experience-in-the-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# This report shows that years and 'in a' clearly stand out

# %%
# What areas should the candidate be experienced in?
my_list_a = ['experience in ','experience in a ','experience in the ']
my_list_b = ['experience-in-','experience-in-a-','experience-in-the-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# This report shows that marketing and fast clearly stand out

# %%
my_list_a = [' marketing ','experience in marketing ',
             'experience in marketing and ','experience in marketing or ',
             'experience in a marketing ','experience in a marketing or ',
             'experience in a marketing role ']
my_list_b = ['-marketing-','experience-in-marketing-',
             'experience-in-marketing-and-','experience-in-marketing-or-',
             'experience-in-a-marketing-','experience-in-a-marketing-or-',
             'experience-in-a-marketing-role-']

i=0
for i in range(7):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %%
# How many years of experience?
my_list_a = [' year ',' years ']
my_list_b = ['-year-','-years-']

i=0
for i in range(2):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# This report shows that years clearly stands out

# %%
# How many years of experience?
my_list_a = [' twelve year experience ',' 12 year experience ',
             ' twelve years experience ',' 12 years experience ',
             ' twelve year of experience ',' 12 year of experience ',
             ' twelve years of experience ',' 12 years of experience ']
my_list_b = ['-twelve-year-experience-','-12-year-experience-',
             '-twelve-years-experience-','-12-years-experience-',
             '-twelve-year-of-experience-','-12-year-of-experience-',
             '-twelve-years-of-experience-','-12-years-of-experience-']

i=0
for i in range(8):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %% [markdown]
# ###### **Management**
# Top expression:  *'project management and'*

# %%
# Let's examine the noun and its descriptor
my_list_a = ['management ',' management',' management ']
my_list_b = ['management-','-management','-management-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " management  "
#                  expression  frequency
# 1070         management-and        196
# 2984      management-skills        104
# 1143          management-of         84
# 4290  management-experience         58
# 3021          management-or         27
#
# Total frequency:  1349
# Total number of expressions:  386
# Minimum frequency:  1
# Maximum frequency:  196
#
# Therefore, the average expression of  " management  "  has a frequency of  3.494818652849741 ;
# some median expressions of  " management  "  are   as shown below:
#                      expression  frequency
# 13166  management-instructional          1
# 13168       management-benefits          1
# 13167      management-inclusion          1
# 13162           management-shrm          1
# 3260        management-blogging          1
# ( " management  "  had  234  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  management "
#                expression  frequency
# 15113  project-management        238
# 15126      and-management         65
# 15111     time-management         64
# 15117  product-management         44
# 15147    brand-management         39
#
# Total frequency:  1358
# Total number of expressions:  287
# Minimum frequency:  1
# Maximum frequency:  238
#
# Therefore, the average expression of  "  management "  has a frequency of  4.7317073170731705 ;
# some median expressions of  "  management "  are   as shown below:
#                    expression  frequency
# 15384       threat-management          1
# 15410    important-management          1
# 15409     diabetes-management          1
# 15385          etc-management          1
# 15180  biosciences-management          1
# ( "  management "  had  162  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  management  "
#                           expression  frequency
# 15437      project-management-skills         46
# 15415         project-management-and         34
# 15561         time-management-skills         29
# 15496              and-management-of         23
# 15474  project-management-experience         19
#
# Total frequency:  1335
# Total number of expressions:  876
# Minimum frequency:  1
# Maximum frequency:  46
#
# Therefore, the average expression of  "  management  "  has a frequency of  1.523972602739726 ;
# some median expressions of  "  management  "  are   as shown below:
#                          expression  frequency
# 15883       asset-management-system          1
# 15881        senior-management-work          1
# 15714        account-management-and          1
# 15880        media-management-tools          1
# 15882  information-management-group          1
# ( "  management  "  had  723  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %%
my_list_a = ['project management ','project management and ',
             ' management experience ','project management and organizational ']
my_list_b = ['project-management-','project-management-and-',
             '-management-experience-','project-management-and-organizational-']

i=0
for i in range(4):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " project management  "
#                          expression  frequency
# 2970      project-management-skills         46
# 1318         project-management-and         34
# 4256  project-management-experience         19
# 3006          project-management-or          6
# 8469     project-management-support          6
#
# Total frequency:  239
# Total number of expressions:  93
# Minimum frequency:  1
# Maximum frequency:  46
#
# Therefore, the average expression of  " project management  "  has a frequency of  2.5698924731182795 ;
# some median expressions of  " project management  "  are   as shown below:
#                               expression  frequency
# 14400      project-management-leadership          1
# 14405  project-management-prioritization          1
# 12286          project-management-social          1
# 14284      project-management-proficient          1
# 11858             project-management-sku          1
# ( " project management  "  had  67  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " project management and  "
#                                   expression  frequency
# 14834  project-management-and-organizational          7
# 14839       project-management-and-execution          2
# 14837  project-management-and-prioritization          2
# 14849           project-management-and-cross          1
# 14845         project-management-and-ability          1
#
# Total frequency:  34
# Total number of expressions:  26
# Minimum frequency:  1
# Maximum frequency:  7
#
# Therefore, the average expression of  " project management and  "  has a frequency of  1.3076923076923077 ;
# some median expressions of  " project management and  "  are   as shown below:
#                                expression  frequency
# 14849        project-management-and-cross          1
# 14845      project-management-and-ability          1
# 14856  project-management-and-stakeholder          1
# 14832     project-management-and-customer          1
# 14848    project-management-and-timelines          1
# ( " project management and  "  had  23  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  management experience  "
#                                     expression  frequency
# 14899   project-management-experience-required          3
# 14858        project-management-experience-and          2
# 14863  project-management-experience-preferred          2
# 14861    project-management-experience-working          2
# 14906     event-management-experience-required          1
#
# Total frequency:  58
# Total number of expressions:  53
# Minimum frequency:  1
# Maximum frequency:  3
#
# Therefore, the average expression of  "  management experience  "  has a frequency of  1.0943396226415094 ;
# some median expressions of  "  management experience  "  are   as shown below:
#                                       expression  frequency
# 14906       event-management-experience-required          1
# 14909          vendor-management-experience-with          1
# 14905           project-management-experience-an          1
# 14908  reputation-management-experience-facebook          1
# 14907     office-management-experience-including          1
# ( "  management experience  "  had  49  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " project management and organizational  "
#                                          expression  frequency
# 14911  project-management-and-organizational-skills          7
#
# Total frequency:  7
# Total number of expressions:  1
# Minimum frequency:  7
# Maximum frequency:  7
#
# Therefore, the average expression of  " project management and organizational  "  has a frequency of  7.0 ;
# some median expressions of  " project management and organizational  "  are   as shown below:
#                                          expression  frequency
# 14911  project-management-and-organizational-skills          7
# ( " project management and organizational  "  had  1  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %%
my_list_a = [' and management']
my_list_b = ['-and-management']

i=0
for i in range(1):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  and management "
#                        expression  frequency
# 14912  development-and-management          9
# 14917     planning-and-management          6
# 14918       design-and-management          3
# 14935     strategy-and-management          3
# 14942    marketing-and-management          3
#
# Total frequency:  67
# Total number of expressions:  39
# Minimum frequency:  1
# Maximum frequency:  9
#
# Therefore, the average expression of  "  and management "  has a frequency of  1.7179487179487178 ;
# some median expressions of  "  and management "  are   as shown below:
#                             expression  frequency
# 14913           conduct-and-management          1
# 14932  analysis-and-managementdecision          1
# 14934        activities-and-management          1
# 14939         diagnosis-and-management          1
# 14940       measurement-and-management          1
# ( "  and management "  had  25  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %% [markdown]
# ###### **Team**
# Top expression:  *'a team of'*

# %%
# Let's examine the noun and its descriptor
my_list_a = ['team ',' team',' team ']
my_list_b = ['team-','-team','-team-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " team  "
#          expression  frequency
# 14969       team-to        200
# 14952  team-members        144
# 14951      team-and        144
# 14963       team-of        103
# 14956       team-in         96
#
# Total frequency:  2111
# Total number of expressions:  419
# Minimum frequency:  1
# Maximum frequency:  200
#
# Therefore, the average expression of  " team  "  has a frequency of  5.0381861575179 ;
# some median expressions of  " team  "  are   as shown below:
#               expression  frequency
# 15150  team-additionally          1
# 15211       team-charged          1
# 15146           team-key          1
# 15148           team-but          1
# 15151        team-embody          1
# ( " team  "  had  266  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  team "
#              expression  frequency
# 15382            a-team        271
# 15371    marketing-team        207
# 15394          the-team        161
# 15387          our-team        127
# 15377  functional-teams         71
#
# Total frequency:  2930
# Total number of expressions:  710
# Minimum frequency:  1
# Maximum frequency:  271
#
# Therefore, the average expression of  "  team "  has a frequency of  4.126760563380282 ;
# some median expressions of  "  team "  are   as shown below:
#             expression  frequency
# 15786  corporate-teams          1
# 15787     angeles-team          1
# 15788       pitch-team          1
# 15783         its-team          1
# 15782         dps-team          1
# ( "  team "  had  423  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  team  "
#                expression  frequency
# 16092           a-team-of         51
# 16125  a-team-environment         40
# 16119   marketing-team-to         28
# 16214       a-team-player         20
# 16105        the-team-and         18
#
# Total frequency:  2099
# Total number of expressions:  1282
# Minimum frequency:  1
# Maximum frequency:  51
#
# Therefore, the average expression of  "  team  "  has a frequency of  1.6372854914196568 ;
# some median expressions of  "  team  "  are   as shown below:
#                       expression  frequency
# 16388    communications-team-has          1
# 16624           programs-team-to          1
# 16389         global-team-medcom          1
# 16652         a-team-contributor          1
# 17300  multidisciplinary-team-to          1
# ( "  team  "  had  1036  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %%
my_list_a = ['a team ','a team of ',
             ' our team',' marketing team to ',' the marketing team to ']
my_list_b = ['a-team-','a-team-of-',
             '-our-team','-marketing-team-to-','-the-marketing-team-to-']

i=0
for i in range(5):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " a team  "
#                expression  frequency
# 16092           a-team-of        153
# 16125  a-team-environment        120
# 16214       a-team-player         60
# 16229          a-team-and         42
# 16606         a-team-that         33
#
# Total frequency:  918
# Total number of expressions:  121
# Minimum frequency:  1
# Maximum frequency:  153
#
# Therefore, the average expression of  " a team  "  has a frequency of  7.586776859504132 ;
# some median expressions of  " a team  "  are   as shown below:
#               expression  frequency
# 16695  a-team-orientated          3
# 17345    a-team-composed          3
# 17039        a-team-self          3
# 16245     a-team-dynamic          3
# 16701      a-team-innate          3
# ( " a team  "  had  62  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " a team of  "
#                   expression  frequency
# 17364        a-team-of-world         14
# 17380     a-team-of-analysts         10
# 17363  a-team-of-researchers          6
# 17378    a-team-of-marketing          6
# 17383      a-team-of-account          4
#
# Total frequency:  102
# Total number of expressions:  32
# Minimum frequency:  2
# Maximum frequency:  14
#
# Therefore, the average expression of  " a team of  "  has a frequency of  3.1875 ;
# some median expressions of  " a team of  "  are   as shown below:
#                     expression  frequency
# 17370         a-team-of-hungry          2
# 17369  a-team-of-professionals          2
# 17371          a-team-of-other          2
# 17368  a-team-of-nutritionists          2
# 17366             a-team-of-ex          2
# ( " a team of  "  had  23  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  our team "
#               expression  frequency
# 17394      join-our-team         80
# 17392        of-our-team         30
# 17408  behavior-our-team         14
# 17407      with-our-team          8
# 17401        to-our-team          8
#
# Total frequency:  278
# Total number of expressions:  59
# Minimum frequency:  2
# Maximum frequency:  80
#
# Therefore, the average expression of  "  our team "  has a frequency of  4.711864406779661 ;
# some median expressions of  "  our team "  are   as shown below:
#                expression  frequency
# 17395    summary-our-team          2
# 17396  what-our-teammates          2
# 17397  solutions-our-team          2
# 17399   maintain-our-team          2
# 17400    focused-our-team          2
# ( "  our team "  had  44  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  marketing team to  "
#                             expression  frequency
# 17462     the-marketing-team-to-ensure          6
# 17457     press-marketing-team-to-help          4
# 17451    our-marketing-team-to-publish          4
# 17463  the-marketing-team-to-translate          2
# 17453   with-marketing-team-to-develop          2
#
# Total frequency:  56
# Total number of expressions:  24
# Minimum frequency:  2
# Maximum frequency:  6
#
# Therefore, the average expression of  "  marketing team to  "  has a frequency of  2.3333333333333335 ;
# some median expressions of  "  marketing team to  "  are   as shown below:
#                             expression  frequency
# 17463  the-marketing-team-to-translate          2
# 17453   with-marketing-team-to-develop          2
# 17454     web-marketing-team-to-define          2
# 17455      the-marketing-team-to-align          2
# 17456    our-marketing-team-to-promote          2
# ( "  marketing team to  "  had  21  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  the marketing team to  "
#                                     expression  frequency
# 17477        with-the-marketing-team-to-ensure          2
# 17481          with-the-marketing-team-to-gain          1
# 17476  and-the-marketing-team-to-conceptualize          1
# 17475         with-the-marketing-team-to-align          1
# 17478     with-the-marketing-team-to-translate          1
#
# Total frequency:  9
# Total number of expressions:  8
# Minimum frequency:  1
# Maximum frequency:  2
#
# Therefore, the average expression of  "  the marketing team to  "  has a frequency of  1.125 ;
# some median expressions of  "  the marketing team to  "  are   as shown below:
#                                     expression  frequency
# 17481          with-the-marketing-team-to-gain          1
# 17476  and-the-marketing-team-to-conceptualize          1
# 17475         with-the-marketing-team-to-align          1
# 17478     with-the-marketing-team-to-translate          1
# 17479     within-the-marketing-team-to-deliver          1
# ( "  the marketing team to  "  had  7  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %%
my_list_a = ['a team of world ','a team of marketing ','a team of account ']
my_list_b = ['a-team-of-world-','a-team-of-marketing-','a-team-of-account-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " a team of world  "
#                         expression  frequency
# 17483  a-team-of-world-researchers          7
#
# Total frequency:  7
# Total number of expressions:  1
# Minimum frequency:  7
# Maximum frequency:  7
#
# Therefore, the average expression of  " a team of world  "  has a frequency of  7.0 ;
# some median expressions of  " a team of world  "  are   as shown below:
#                         expression  frequency
# 17483  a-team-of-world-researchers          7
# ( " a team of world  "  had  1  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " a team of marketing  "
#                               expression  frequency
# 17485      a-team-of-marketing-personnel          1
# 17484            a-team-of-marketing-and          1
# 17486  a-team-of-marketing-professionals          1
#
# Total frequency:  3
# Total number of expressions:  3
# Minimum frequency:  1
# Maximum frequency:  1
#
# Therefore, the average expression of  " a team of marketing  "  has a frequency of  1.0 ;
# some median expressions of  " a team of marketing  "  are   as shown below:
#                               expression  frequency
# 17485      a-team-of-marketing-personnel          1
# 17484            a-team-of-marketing-and          1
# 17486  a-team-of-marketing-professionals          1
# ( " a team of marketing  "  had  3  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " a team of account  "
#                          expression  frequency
# 17487  a-team-of-account-executives          1
# 17488    a-team-of-account-managers          1
#
# Total frequency:  2
# Total number of expressions:  2
# Minimum frequency:  1
# Maximum frequency:  1
#
# Therefore, the average expression of  " a team of account  "  has a frequency of  1.0 ;
# some median expressions of  " a team of account  "  are   as shown below:
#                          expression  frequency
# 17487  a-team-of-account-executives          1
# 17488    a-team-of-account-managers          1
# ( " a team of account  "  had  2  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %% [markdown]
# ###### **Skills**
# Top expression:  *'knowledge skills and'*

# %%
# Let's examine the noun and its descriptor
my_list_a = [' skills ','skills ',' skills']
my_list_b = ['-skills-','skills-','-skills']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %%
my_list_a = ['knowledge skills and ',' knowledge skills and',' knowledge skills and ']
my_list_b = ['knowledge-skills-and-','-knowledge-skills-and','-knowledge-skills-and-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %%
my_list_a = ['communication skills ',' communication skills',' and communication skills']
my_list_b = ['communication-skills-','-communication-skills','-and-communication-skills']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])

# %% [markdown]
# ###### **Research**
# Top expression:  *'market research and'*

# %% [markdown]
# ###### **Business**
# Top expression:  *'small business expand'*

# %% [markdown]
# ###### **Marketing**
# Top expression:  *'of marketing and'*

# %% [markdown]
# ###### **Data**
# Top expression:  *'of data and'*

# %% [markdown]
# ##### *Top Verb Expressions (Based on the top 5 values for each verb association independent of the other words)*

# %% [markdown]
# ###### **Is**
# Top expression:  *'this is a'*

# %%
# Let's examine the verb and its descriptor
my_list_a = ['this is a ',' this is a',' this is a ']
my_list_b = ['this-is-a-','-this-is-a','-this-is-a-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " this is a  "
#                 expression  frequency
# 19176       this-is-a-full         15
# 19186       this-is-a-paid         10
# 19184       this-is-a-part          4
# 19179  this-is-a-wonderful          4
# 19199      this-is-a-great          3
#
# Total frequency:  80
# Total number of expressions:  42
# Minimum frequency:  1
# Maximum frequency:  15
#
# Therefore, the average expression of  " this is a  "  has a frequency of  1.9047619047619047 ;
# some median expressions of  " this is a  "  are   as shown below:
#                 expression  frequency
# 19215     this-is-a-chance          1
# 19214  this-is-a-permanent          1
# 19213      this-is-a-union          1
# 19204        this-is-a-key          1
# 19203  this-is-a-freelance          1
# ( " this is a  "  had  31  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  this is a "
#            expression  frequency
# 19234      -this-is-a          6
# 19224  base-this-is-a          4
# 19226     -this-is-an          4
# 19238  team-this-is-a          4
# 19228  2020-this-is-a          3
#
# Total frequency:  111
# Total number of expressions:  86
# Minimum frequency:  1
# Maximum frequency:  6
#
# Therefore, the average expression of  "  this is a "  has a frequency of  1.2906976744186047 ;
# some median expressions of  "  this is a "  are   as shown below:
#                  expression  frequency
# 19293    employee-this-is-a          1
# 19299     content-this-is-a          1
# 19275    required-this-is-a          1
# 19298       media-this-is-a          1
# 19274  individual-this-is-a          1
# ( "  this is a "  had  72  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  this is a  "
#                          expression  frequency
# 19306      base-this-is-a-wonderful          4
# 19308           2020-this-is-a-full          3
# 19328  opportunities-this-is-a-paid          2
# 19337          books-this-is-a-must          2
# 19311                -this-is-a-fun          2
#
# Total frequency:  80
# Total number of expressions:  71
# Minimum frequency:  1
# Maximum frequency:  4
#
# Therefore, the average expression of  "  this is a  "  has a frequency of  1.1267605633802817 ;
# some median expressions of  "  this is a  "  are   as shown below:
#                              expression  frequency
# 19318  differences-this-is-a-reflection          1
# 19307            agency-this-is-a-hands          1
# 19309        socialmedia-this-is-a-very          1
# 19310       position-this-is-a-clinical          1
# 19312                   -this-is-a-part          1
# ( "  this is a  "  had  65  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %% [markdown]
# ###### **Have**
# Top expression:  *'you have a'*

# %%
# Let's examine the verb and its descriptor
my_list_a = ['have ',' have',' have ']
my_list_b = ['have-','-have','-have-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " have  "
#            expression  frequency
# 963            have-a        255
# 74           have-the        136
# 546           have-an         57
# 3294  have-experience         37
# 1932      have-strong         35
#
# Total frequency:  1081
# Total number of expressions:  247
# Minimum frequency:  1
# Maximum frequency:  255
#
# Therefore, the average expression of  " have  "  has a frequency of  4.376518218623482 ;
# some median expressions of  " have  "  are   as shown below:
#            expression  frequency
# 12336       behave-in          1
# 14099  have-satisfied          1
# 12467     have-lapsed          1
# 14925          have-2          1
# 11977     have-expert          1
# ( " have  "  had  146  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  have "
#       expression  frequency
# 14969  must-have        178
# 14968   you-have        153
# 14970  will-have        146
# 14971    we-have        110
# 14977   and-have         74
#
# Total frequency:  1086
# Total number of expressions:  150
# Minimum frequency:  1
# Maximum frequency:  178
#
# Therefore, the average expression of  "  have "  has a frequency of  7.24 ;
# some median expressions of  "  have "  are   as shown below:
#             expression  frequency
# 15076  engagement-have          1
# 15099        what-have          1
# 15064        anet-have          1
# 15100      growth-have          1
# 15034        york-have          1
# ( "  have "  had  100  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  have  "
#           expression  frequency
# 15143     you-have-a         51
# 15171  will-have-the         38
# 15175    will-have-a         38
# 15169    must-have-a         34
# 15204      we-have-a         28
#
# Total frequency:  1077
# Total number of expressions:  516
# Minimum frequency:  1
# Maximum frequency:  51
#
# Therefore, the average expression of  "  have  "  has a frequency of  2.0872093023255816 ;
# some median expressions of  "  have  "  are   as shown below:
#              expression  frequency
# 15416     anet-have-the          1
# 15399       to-have-you          1
# 15435   you-have-worked          1
# 15400  also-have-direct          1
# 15421  you-have-working          1
# ( "  have  "  had  388  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %%
# Let's examine the verb and its descriptor
my_list_a = ['you have ','you have a ','you have an ','you have the ',
             'you have experience ','you have strong ','we have ','we have a ',
             'we have an ','we have the ','we have experience ','we have strong ']
my_list_b = ['you-have-','you-have-a-','you-have-an-','you-have-the-',
             'you-have-experience-','you-have-strong-','we-have-','we-have-a-',
             'we-have-an-','we-have-the-','we-have-experience-','we-have-strong-']

i=0
for i in range(12):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " you have  "
#                 expression  frequency
# 15143           you-have-a        102
# 15135         you-have-the         34
# 15180  you-have-experience         26
# 15338   you-have-questions         10
# 15195    you-have-inflated         10
#
# Total frequency:  306
# Total number of expressions:  49
# Minimum frequency:  2
# Maximum frequency:  102
#
# Therefore, the average expression of  " you have  "  has a frequency of  6.244897959183674 ;
# some median expressions of  " you have  "  are   as shown below:
#                expression  frequency
# 15523          you-have-6          2
# 15396  you-have-marketing          2
# 15520       you-have-with          2
# 15322         you-have-at          2
# 15183  you-have-navigated          2
# ( " you have  "  had  34  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " you have a  "
#                   expression  frequency
# 15655     you-have-a-passion         10
# 15675  you-have-a-disability          3
# 15670       you-have-a-depth          2
# 15660    you-have-a-bachelor          2
# 15664      you-have-a-proven          2
#
# Total frequency:  51
# Total number of expressions:  35
# Minimum frequency:  1
# Maximum frequency:  10
#
# Therefore, the average expression of  " you have a  "  has a frequency of  1.457142857142857 ;
# some median expressions of  " you have a  "  are   as shown below:
#                  expression  frequency
# 15685  you-have-a-portfolio          1
# 15684       you-have-a-life          1
# 15665   you-have-a-thorough          1
# 15667       you-have-a-wide          1
# 15674     you-have-a-unique          1
# ( " you have a  "  had  28  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " you have an  "
#                    expression  frequency
# 15687  you-have-an-insatiable          2
# 15688    you-have-an-aptitude          1
#
# Total frequency:  3
# Total number of expressions:  2
# Minimum frequency:  1
# Maximum frequency:  2
#
# Therefore, the average expression of  " you have an  "  has a frequency of  1.5 ;
# some median expressions of  " you have an  "  are   as shown below:
# Empty DataFrame
# Columns: [expression, frequency]
# Index: []
# ( " you have an  "  had  0  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " you have the  "
#                      expression  frequency
# 15691  you-have-the-opportunity          3
# 15689       you-have-the-talent          2
# 15690    you-have-the-attention          2
# 15693   you-have-the-experience          2
# 15697       you-have-the-chance          1
#
# Total frequency:  17
# Total number of expressions:  12
# Minimum frequency:  1
# Maximum frequency:  3
#
# Therefore, the average expression of  " you have the  "  has a frequency of  1.4166666666666667 ;
# some median expressions of  " you have the  "  are   as shown below:
#                    expression  frequency
# 15697     you-have-the-chance          1
# 15698        you-have-the-eye          1
# 15699    you-have-the-benefit          1
# 15696  you-have-the-integrity          1
# 15692    you-have-the-ability          1
# ( " you have the  "  had  8  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " you have experience  "
#                            expression  frequency
# 15704          you-have-experience-in          4
# 15703     you-have-experience-working          3
# 15701        you-have-experience-with          2
# 15706    you-have-experience-managing          2
# 15702  you-have-experience-performing          1
#
# Total frequency:  13
# Total number of expressions:  6
# Minimum frequency:  1
# Maximum frequency:  4
#
# Therefore, the average expression of  " you have experience  "  has a frequency of  2.1666666666666665 ;
# some median expressions of  " you have experience  "  are   as shown below:
#                          expression  frequency
# 15701      you-have-experience-with          2
# 15706  you-have-experience-managing          2
# ( " you have experience  "  had  2  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " you have strong  "
# Empty DataFrame
# Columns: [expression, frequency]
# Index: []
#
# Total frequency:  0
# Total number of expressions:  0
# Minimum frequency:  nan
# Maximum frequency:  nan
#
# Therefore, the average expression of  " you have strong  "  has a frequency of  nan ;
# some median expressions of  " you have strong  "  are   as shown below:
# Empty DataFrame
# Columns: [expression, frequency]
# Index: []
# ( " you have strong  "  had  0  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in long_scalars
# Top 5 expressions for:  " we have  "
#             expression  frequency
# 15204        we-have-a         56
# 15139       we-have-an         30
# 15138  we-have-amazing          8
# 15140     we-have-some          8
# 15162      we-have-the          8
#
# Total frequency:  220
# Total number of expressions:  52
# Minimum frequency:  2
# Maximum frequency:  56
#
# Therefore, the average expression of  " we have  "  has a frequency of  4.230769230769231 ;
# some median expressions of  " we have  "  are   as shown below:
#                 expression  frequency
# 15621           we-have-in          2
# 15321          we-have-big          2
# 15631     we-have-assisted          2
# 15648         we-have-more          2
# 15308  we-have-researchers          2
# ( " we have  "  had  41  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " we have a  "
#              expression  frequency
# 15721    we-have-a-well          3
# 15718    we-have-a-team          2
# 15710   we-have-a-great          2
# 15720   we-have-a-large          2
# 15725  we-have-a-direct          1
#
# Total frequency:  28
# Total number of expressions:  23
# Minimum frequency:  1
# Maximum frequency:  3
#
# Therefore, the average expression of  " we have a  "  has a frequency of  1.2173913043478262 ;
# some median expressions of  " we have a  "  are   as shown below:
#                 expression  frequency
# 15725     we-have-a-direct          1
# 15726    we-have-a-variety          1
# 15728     we-have-a-casual          1
# 15727     we-have-a-strong          1
# 15723  we-have-a-portfolio          1
# ( " we have a  "  had  19  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " we have an  "
#                    expression  frequency
# 15731     we-have-an-exciting          4
# 15736   we-have-an-integrated          2
# 15730   we-have-an-incredible          2
# 15732  we-have-an-appropriate          1
# 15733    we-have-an-unbridled          1
#
# Total frequency:  15
# Total number of expressions:  10
# Minimum frequency:  1
# Maximum frequency:  4
#
# Therefore, the average expression of  " we have an  "  has a frequency of  1.5 ;
# some median expressions of  " we have an  "  are   as shown below:
#                        expression  frequency
# 15732      we-have-an-appropriate          1
# 15733        we-have-an-unbridled          1
# 15734      we-have-an-opportunity          1
# 15735          we-have-an-opening          1
# 15737  we-have-an-entrepreneurial          1
# ( " we have an  "  had  7  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " we have the  "
#                     expression  frequency
# 15741  we-have-the-opportunity          1
# 15742        we-have-the-power          1
# 15740     we-have-the-workload          1
# 15743    we-have-the-expertise          1
#
# Total frequency:  4
# Total number of expressions:  4
# Minimum frequency:  1
# Maximum frequency:  1
#
# Therefore, the average expression of  " we have the  "  has a frequency of  1.0 ;
# some median expressions of  " we have the  "  are   as shown below:
#                     expression  frequency
# 15741  we-have-the-opportunity          1
# 15742        we-have-the-power          1
# 15740     we-have-the-workload          1
# 15743    we-have-the-expertise          1
# ( " we have the  "  had  4  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " we have experience  "
# Empty DataFrame
# Columns: [expression, frequency]
# Index: []
#
# Total frequency:  0
# Total number of expressions:  0
# Minimum frequency:  nan
# Maximum frequency:  nan
#
# Therefore, the average expression of  " we have experience  "  has a frequency of  nan ;
# some median expressions of  " we have experience  "  are   as shown below:
# Empty DataFrame
# Columns: [expression, frequency]
# Index: []
# ( " we have experience  "  had  0  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " we have strong  "
# Empty DataFrame
# Columns: [expression, frequency]
# Index: []
#
# Total frequency:  0
# Total number of expressions:  0
# Minimum frequency:  nan
# Maximum frequency:  nan
#
# Therefore, the average expression of  " we have strong  "  has a frequency of  nan ;
# some median expressions of  " we have strong  "  are   as shown below:
# Empty DataFrame
# Columns: [expression, frequency]
# Index: []
# ( " we have strong  "  had  0  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %% [markdown]
# ###### **Are**
# Top expression:  *'we are looking'*

# %%
# Let's examine the verb and its descriptor
my_list_a = ['are ',' are',' are ']
my_list_b = ['are-','-are','-are-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " are  "
#         expression  frequency
# 15776  are-looking        118
# 15765        are-a        108
# 15750      are-not         76
# 15784       are-an         71
# 15757      are-you         67
#
# Total frequency:  3155
# Total number of expressions:  1021
# Minimum frequency:  1
# Maximum frequency:  118
#
# Therefore, the average expression of  " are  "  has a frequency of  3.090107737512243 ;
# some median expressions of  " are  "  are   as shown below:
#                  expression  frequency
# 16662  healthcare-providers          1
# 16307            are-backed          1
# 16309            are-iconic          1
# 16299       software-allows          1
# 16298               are-for          1
# ( " are  "  had  629  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  are "
#       expression  frequency
# 16781     we-are        570
# 16775    you-are        260
# 16798    who-are         80
# 16768   that-are         77
# 16796    and-are         60
#
# Total frequency:  2612
# Total number of expressions:  613
# Minimum frequency:  1
# Maximum frequency:  570
#
# Therefore, the average expression of  "  are "  has a frequency of  4.261011419249592 ;
# some median expressions of  "  are "  are   as shown below:
#              expression  frequency
# 16851       focus-areas          1
# 16854     abilities-are          1
# 16832      storage-area          1
# 16835     philips-arena          1
# 16829  independence-are          1
# ( "  are "  had  383  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  are  "
#            expression  frequency
# 17402  we-are-looking        106
# 17411       we-are-an         56
# 17412  we-are-seeking         43
# 17502        we-are-a         41
# 17394       you-are-a         40
#
# Total frequency:  2172
# Total number of expressions:  1147
# Minimum frequency:  1
# Maximum frequency:  106
#
# Therefore, the average expression of  "  are  "  has a frequency of  1.893635571054926 ;
# some median expressions of  "  are  "  are   as shown below:
#                  expression  frequency
# 17669  women-are-encouraged          1
# 17666      talents-are-able          1
# 17668           we-are-dyno          1
# 17670   solutions-are-based          1
# 17672       who-are-focused          1
# ( "  are  "  had  899  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %%
# Let's examine the verb and its descriptor
my_list_a = ['you are ','you are a ','you are an ','we are ','we are a ','we are an ']
my_list_b = ['you-are-','you-are-a-','you-are-an-','we-are-','we-are-a-','we-are-an-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " you are  "
#                expression  frequency
# 17394           you-are-a         80
# 17459  you-are-interested         42
# 17462          you-are-an         22
# 17477      you-are-unable         20
# 17472    you-are-selected         20
#
# Total frequency:  520
# Total number of expressions:  88
# Minimum frequency:  2
# Maximum frequency:  80
#
# Therefore, the average expression of  " you are  "  has a frequency of  5.909090909090909 ;
# some median expressions of  " you are  "  are   as shown below:
#               expression  frequency
# 18143       you-are-keen          2
# 18115      you-are-smart          2
# 18155  you-are-associate          2
# 17959  you-are-motivated          2
# 17979      you-are-proud          2
# ( " you are  "  had  47  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " you are a  "
#                expression  frequency
# 18525   you-are-a-veteran          5
# 18541  you-are-a-creative          2
# 18524   you-are-a-current          2
# 18529      you-are-a-team          2
# 18534     you-are-a-great          2
#
# Total frequency:  40
# Total number of expressions:  31
# Minimum frequency:  1
# Maximum frequency:  5
#
# Therefore, the average expression of  " you are a  "  has a frequency of  1.2903225806451613 ;
# some median expressions of  " you are a  "  are   as shown below:
#                  expression  frequency
# 18532     you-are-a-curious          1
# 18533     you-are-a-skilled          1
# 18535  you-are-a-empathetic          1
# 18536  you-are-a-creatively          1
# 18537        you-are-a-tech          1
# ( " you are a  "  had  25  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " you are an  "
#                   expression  frequency
# 18557  you-are-an-individual          5
# 18555      you-are-an-expert          2
# 18559   you-are-an-effective          1
# 18558    you-are-an-integral          1
# 18556   you-are-an-essential          1
#
# Total frequency:  11
# Total number of expressions:  6
# Minimum frequency:  1
# Maximum frequency:  5
#
# Therefore, the average expression of  " you are an  "  has a frequency of  1.8333333333333333 ;
# some median expressions of  " you are an  "  are   as shown below:
#                   expression  frequency
# 18559   you-are-an-effective          1
# 18558    you-are-an-integral          1
# 18556   you-are-an-essential          1
# 18560  you-are-an-impressive          1
# ( " you are an  "  had  4  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %%
# Let's examine the verb and its descriptor
my_list_a = ['you re ','you re a ','you re an ','we re ','we re a ','we re an ']
my_list_b = ['you-re-','you-re-a-','you-re-an-','we-re-','we-re-a-','we-re-an-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " you re  "
#               expression  frequency
# 18568           you-re-a         10
# 18562         you-re-the          8
# 18584     you-re-looking          7
# 18563       you-re-ready          5
# 18565  you-re-interested          5
#
# Total frequency:  102
# Total number of expressions:  52
# Minimum frequency:  1
# Maximum frequency:  10
#
# Therefore, the average expression of  " you re  "  has a frequency of  1.9615384615384615 ;
# some median expressions of  " you re  "  are   as shown below:
#                expression  frequency
# 18564  you-re-comfortable          1
# 18566    you-re-available          1
# 18567        you-re-eager          1
# 18569      you-re-hitting          1
# 18570     you-re-actually          1
# ( " you re  "  had  35  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " you re a  "
#               expression  frequency
# 18617      you-re-a-good          2
# 18616  you-re-a-creative          2
# 18615    you-re-a-master          1
# 18614  you-re-a-seasoned          1
# 18613     you-re-a-quick          1
#
# Total frequency:  10
# Total number of expressions:  8
# Minimum frequency:  1
# Maximum frequency:  2
#
# Therefore, the average expression of  " you re a  "  has a frequency of  1.25 ;
# some median expressions of  " you re a  "  are   as shown below:
#               expression  frequency
# 18615    you-re-a-master          1
# 18614  you-re-a-seasoned          1
# 18613     you-re-a-quick          1
# 18619      you-re-a-fast          1
# 18618      you-re-a-tech          1
# ( " you re a  "  had  6  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " you re an  "
#                    expression  frequency
# 18621        you-re-an-intern          1
# 18622  you-re-an-encyclopedia          1
# 18623     you-re-an-ambitious          1
#
# Total frequency:  3
# Total number of expressions:  3
# Minimum frequency:  1
# Maximum frequency:  1
#
# Therefore, the average expression of  " you re an  "  has a frequency of  1.0 ;
# some median expressions of  " you re an  "  are   as shown below:
#                    expression  frequency
# 18621        you-re-an-intern          1
# 18622  you-re-an-encyclopedia          1
# 18623     you-re-an-ambitious          1
# ( " you re an  "  had  3  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %%
my_list_a = [' skills are a must','what we are looking ',' are a ']
my_list_b = ['-skills-are-a-must','what-we-are-looking-','-are-a-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  skills are a must "
#                             expression  frequency
# 25082  communication-skills-are-a-must          2
# 25085   proofreading-skills-are-a-must          2
# 25083     management-skills-are-a-must          1
# 25084        writing-skills-are-a-must          1
#
# Total frequency:  6
# Total number of expressions:  4
# Minimum frequency:  1
# Maximum frequency:  2
#
# Therefore, the average expression of  "  skills are a must "  has a frequency of  1.5 ;
# some median expressions of  "  skills are a must "  are   as shown below:
# Empty DataFrame
# Columns: [expression, frequency]
# Index: []
# ( "  skills are a must "  had  0  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " what we are looking  "
#                     expression  frequency
# 25086  what-we-are-looking-for         14
#
# Total frequency:  14
# Total number of expressions:  1
# Minimum frequency:  14
# Maximum frequency:  14
#
# Therefore, the average expression of  " what we are looking  "  has a frequency of  14.0 ;
# some median expressions of  " what we are looking  "  are   as shown below:
#                     expression  frequency
# 25086  what-we-are-looking-for         14
# ( " what we are looking  "  had  1  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  are a  "
#               expression  frequency
# 25023    we-are-a-global         14
# 25014  skills-are-a-must         12
# 25008  you-are-a-veteran         10
# 25040   we-are-a-company          8
# 25029  skills-are-a-plus          6
#
# Total frequency:  222
# Total number of expressions:  80
# Minimum frequency:  1
# Maximum frequency:  14
#
# Therefore, the average expression of  "  are a  "  has a frequency of  2.775 ;
# some median expressions of  "  are a  "  are   as shown below:
#                   expression  frequency
# 25007  careers-are-a-journey          2
# 25009      you-are-a-federal          2
# 25010     you-are-a-friendly          2
# 25011       you-are-a-gifted          2
# 25013       we-are-a-florida          2
# ( "  are a  "  had  63  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %% [markdown]
# ###### **Be**
# Top expression:  *'must be able'*

# %%
# Let's examine the verb and its descriptor
my_list_a = ['be ',' be',' be ']
my_list_b = ['be-','-be','-be-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " be  "
#            expression  frequency
# 19377            be-a        207
# 19378         be-able        202
# 19385  be-responsible        145
# 19373           be-an        103
# 19388     be-required         81
#
# Total frequency:  2594
# Total number of expressions:  584
# Minimum frequency:  1
# Maximum frequency:  207
#
# Therefore, the average expression of  " be  "  has a frequency of  4.441780821917808 ;
# some median expressions of  " be  "  are   as shown below:
#           expression  frequency
# 19872           be-i          1
# 19491      be-marked          1
# 19846  be-constantly          1
# 19497           be-o          1
# 19946    be-nurtured          1
# ( " be  "  had  337  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  be "
#       expression  frequency
# 19955    will-be        698
# 19954      to-be        424
# 19956    must-be        404
# 19967     may-be        216
# 19970   the-best        143
#
# Total frequency:  4969
# Total number of expressions:  1200
# Minimum frequency:  1
# Maximum frequency:  698
#
# Therefore, the average expression of  "  be "  has a frequency of  4.140833333333333 ;
# some median expressions of  "  be "  are   as shown below:
#                   expression  frequency
# 20174      comfortable-being          1
# 20384         environment-be          1
# 21038        delivering-beer          1
# 21039         festivals-beer          1
# 21099  capabilities-benefits          1
# ( "  be "  had  830  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  "  be  "
#                 expression  frequency
# 21131         must-be-able        120
# 21143  will-be-responsible        112
# 21126             to-be-an         57
# 21142            will-be-a         55
# 21141              to-be-a         47
#
# Total frequency:  2400
# Total number of expressions:  876
# Minimum frequency:  1
# Maximum frequency:  120
#
# Therefore, the average expression of  "  be  "  has a frequency of  2.73972602739726 ;
# some median expressions of  "  be  "  are   as shown below:
#                 expression  frequency
# 21565   will-be-recognized          1
# 21760       can-be-adapted          1
# 21751           value-be-a          1
# 21752  disposition-be-self          1
# 21753  also-be-encouraging          1
# ( "  be  "  had  595  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------

# %%
my_list_a = ['be responsible for ','must be able to ','will be required to ']
my_list_b = ['be-responsible-for-','must-be-able-to-','will-be-required-to-']

i=0
for i in range(3):
  phrase_reporter(pattern_a=my_list_a[i],
                  pattern_b=my_list_b[i])
# Out:
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " be responsible for  "
#                           expression  frequency
# 22051         be-responsible-for-the         28
# 22040  be-responsible-for-supporting         16
# 22062  be-responsible-for-developing         16
# 22054   be-responsible-for-assisting         16
# 22089     be-responsible-for-driving         10
#
# Total frequency:  274
# Total number of expressions:  76
# Minimum frequency:  2
# Maximum frequency:  28
#
# Therefore, the average expression of  " be responsible for  "  has a frequency of  3.6052631578947367 ;
# some median expressions of  " be responsible for  "  are   as shown below:
#                           expression  frequency
# 22044       be-responsible-for-their          2
# 22111   be-responsible-for-tradeshow          2
# 22043        be-responsible-for-fees          2
# 22052     be-responsible-for-setting          2
# 22050  be-responsible-for-conducting          2
# ( " be responsible for  "  had  53  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " must be able to  "
#                         expression  frequency
# 22125         must-be-able-to-work         27
# 22126      must-be-able-to-perform         16
# 22139         must-be-able-to-lift          5
# 22131  must-be-able-to-demonstrate          3
# 22136        must-be-able-to-multi          3
#
# Total frequency:  120
# Total number of expressions:  57
# Minimum frequency:  1
# Maximum frequency:  27
#
# Therefore, the average expression of  " must be able to  "  has a frequency of  2.1052631578947367 ;
# some median expressions of  " must be able to  "  are   as shown below:
#                           expression  frequency
# 22128       must-be-able-to-complete          1
# 22129      must-be-able-to-transform          1
# 22134         must-be-able-to-thrive          1
# 22178  must-be-able-to-independently          1
# 22177        must-be-able-to-support          1
# ( " must be able to  "  had  40  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
#
# Warning: Restart raw data and function cells before running this instance of the function
# Top 5 expressions for:  " will be required to  "
#                            expression  frequency
# 22116  will-be-required-to-articulate         12
# 22113        will-be-required-to-work          6
# 22115    will-be-required-to-complete          4
# 22114      will-be-required-to-verify          4
# 22118        will-be-required-to-pass          4
#
# Total frequency:  44
# Total number of expressions:  12
# Minimum frequency:  2
# Maximum frequency:  12
#
# Therefore, the average expression of  " will be required to  "  has a frequency of  3.6666666666666665 ;
# some median expressions of  " will be required to  "  are   as shown below:
#                         expression  frequency
# 22121  will-be-required-to-perform          2
# 22120   will-be-required-to-obtain          2
# 22119  will-be-required-to-provide          2
# 22117   will-be-required-to-larger          2
# 22122   will-be-required-to-travel          2
# ( " will be required to  "  had  7  median expressions
# -----END OF ANALYSIS-----
#
# ---------------------------------------------------------------------
